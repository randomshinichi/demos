# %% [markdown]
# ## Predator Prey Agent-based modelling
#
# There are a lot of possible ABMs for any given phenomenon. cadCAD allows you to add, modify and remove simulation blocks and steps at will.
#
# For this demo, we'll adopt a model based on a grid world, on which preys and predators take the following actions at each timestep of their lifes:
#
# 1. Food is grown on every site.
# 2. All agents digest some of the food on their stomach and get older.
# 3. All agents move (if possible) to an available random neighboring location.
# 4. The agents reproduce themselves if there is an available partner nearby
# 5. The prey agents feed on the available food
# 6. The predator agents hunts the nearby preys
# 7. All old enough agents die
#
# There is an inherent stochastic nature on this model, and every time that you run it, we'll have a completely different result for the same parameters. But we can see that there is sort of a random equilibrium that converges to the dynamical equilibrium which we presented on the dynamical simulation.
#
# ABMs tend to produce rich, high density datasets. We'll plot some of this data, but invite the reader to fork this repository and trace the network relations between the agents, or the geospatial statistics around the ABM, for example.

# %%
# Dependences
import pandas as pd
import numpy as np

# Experiments
from model import run
from model.parts.utils import *
pd.options.display.float_format = '{:.2f}'.format

# %matplotlib inline

df = run.run()
rdf = run.postprocessing(df)
# Out:
#                   ___________    ____
#   ________ __ ___/ / ____/   |  / __ \
#  / ___/ __` / __  / /   / /| | / / / /
# / /__/ /_/ / /_/ / /___/ ___ |/ /_/ /
# \___/\__,_/\__,_/\____/_/  |_/_____/
# by cadCAD
#
# Execution Mode: local_proc
# Configuration Count: 1
# Dimensions of the first simulation: (Timesteps, Params, Runs, Vars) = (300, 8, 6, 2)
# Execution Method: local_simulations
# SimIDs   : [0, 0, 0, 0, 0, 0]
# SubsetIDs: [0, 0, 0, 0, 0, 0]
# Ns       : [0, 1, 2, 3, 4, 5]
# ExpIDs   : [0, 0, 0, 0, 0, 0]
# Execution Mode: parallelized
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# Traceback (most recent call last):
#   File "/home/shinichi/.virtualenvs/cadcad/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3418, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-1-95f09d615ad9>", line 12, in <module>
#     df = run.run()
#   File "/home/shinichi/demos/demos/Agent_Based_Modeling/prey_predator_abm/model/run.py", line 17, in run
#     raw_system_events, tensor_field, sessions = simulation.execute()
#   File "/home/shinichi/.virtualenvs/cadcad/lib/python3.8/site-packages/cadCAD/engine/__init__.py", line 151, in execute
#     simulations_results = self.exec_method(
#   File "/home/shinichi/.virtualenvs/cadcad/lib/python3.8/site-packages/cadCAD/engine/execution.py", line 141, in local_simulations
#     return parallelize_simulations(
#   File "/home/shinichi/.virtualenvs/cadcad/lib/python3.8/site-packages/cadCAD/engine/execution.py", line 103, in parallelize_simulations
#     results = flatten(list(map(lambda params: threaded_executor(params), new_params)))
#   File "/home/shinichi/.virtualenvs/cadcad/lib/python3.8/site-packages/cadCAD/engine/execution.py", line 103, in <lambda>
#     results = flatten(list(map(lambda params: threaded_executor(params), new_params)))
#   File "/home/shinichi/.virtualenvs/cadcad/lib/python3.8/site-packages/cadCAD/engine/execution.py", line 92, in threaded_executor
#     results = tp.map(
#   File "/home/shinichi/.virtualenvs/cadcad/lib/python3.8/site-packages/multiprocess/pool.py", line 364, in map
#     return self._map_async(func, iterable, mapstar, chunksize).get()
#   File "/home/shinichi/.virtualenvs/cadcad/lib/python3.8/site-packages/multiprocess/pool.py", line 765, in get
#     self.wait(timeout)
#   File "/home/shinichi/.virtualenvs/cadcad/lib/python3.8/site-packages/multiprocess/pool.py", line 762, in wait
#     self._event.wait(timeout)
#   File "/usr/lib/python3.8/threading.py", line 558, in wait
#     signaled = self._cond.wait(timeout)
#   File "/usr/lib/python3.8/threading.py", line 302, in wait
#     waiter.acquire()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/shinichi/.virtualenvs/cadcad/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2045, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/shinichi/.virtualenvs/cadcad/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1170, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/shinichi/.virtualenvs/cadcad/lib/python3.8/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/home/shinichi/.virtualenvs/cadcad/lib/python3.8/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.8/inspect.py", line 1503, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.8/inspect.py", line 1461, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.8/inspect.py", line 708, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/usr/lib/python3.8/inspect.py", line 754, in getmodule
#     os.path.realpath(f)] = module.__name__
#   File "/usr/lib/python3.8/posixpath.py", line 391, in realpath
#     path, ok = _joinrealpath(filename[:0], filename, {})
#   File "/usr/lib/python3.8/posixpath.py", line 425, in _joinrealpath
#     if not islink(newpath):
#   File "/usr/lib/python3.8/posixpath.py", line 167, in islink
#     st = os.lstat(path)
# KeyboardInterrupt

# %%
rdf.head()
rdf.tail()
# Out:
#        timestep  run  prey_count  predator_count  omnivore_count  \
# 14373       296    6           0               0               0
# 14381       297    6           0               0               0
# 14389       298    6           0               0               0
# 14397       299    6           0               0               0
# 14405       300    6           0               0               0
#
#        food_at_sites  food_at_prey  food_at_predators  food_at_omnivores  \
# 14373        4000.00          0.00               0.00               0.00
# 14381        4000.00          0.00               0.00               0.00
# 14389        4000.00          0.00               0.00               0.00
# 14397        4000.00          0.00               0.00               0.00
# 14405        4000.00          0.00               0.00               0.00
#
#        median_site_food  median_prey_food  median_predator_food  \
# 14373             10.00               NaN                   NaN
# 14381             10.00               NaN                   NaN
# 14389             10.00               NaN                   NaN
# 14397             10.00               NaN                   NaN
# 14405             10.00               NaN                   NaN
#
#        median_omnivore_food  prey_median_age  predator_median_age  \
# 14373                   NaN              NaN                  NaN
# 14381                   NaN              NaN                  NaN
# 14389                   NaN              NaN                  NaN
# 14397                   NaN              NaN                  NaN
# 14405                   NaN              NaN                  NaN
#
#        omnivore_median_age
# 14373                  NaN
# 14381                  NaN
# 14389                  NaN
# 14397                  NaN
# 14405                  NaN

# %% [markdown]
# ### Prey predator phase space
#
# Note that it sorts of converges, in a chaotic manner, to the dynamical system model

# %%
monte_carlo_plot(rdf,'timestep','timestep','prey_count',6)
monte_carlo_plot(rdf,'timestep','timestep','predator_count',6)
monte_carlo_plot(rdf,'timestep','timestep','omnivore_count',6)

# %% [markdown]
# ### Prey prevalence vs food availability on the world
#
# There is an inverse relation between the available food on the grid, and the number of prey.
#
# From the code, can you tell why there is higher variance when the number of prey is higher?

# %%
monte_carlo_plot(rdf,'timestep','timestep','food_at_sites',6)

# %% [markdown]
# #### Food inside agents stomachs
#
# On average, the prey stomachs are always quite full, while the predators stomachs contents vary more.

# %%
monte_carlo_plot(rdf,'timestep','timestep','median_prey_food',6)
monte_carlo_plot(rdf,'timestep','timestep','median_predator_food',6)
monte_carlo_plot(rdf,'timestep','timestep','median_omnivore_food',6)

# %% [markdown]
# #### Predator and Prey median age
#
# On average, this result is cyclical

# %%
monte_carlo_plot(rdf,'timestep','timestep','prey_median_age',6)
monte_carlo_plot(rdf,'timestep','timestep','predator_median_age',6)
monte_carlo_plot(rdf,'timestep','timestep','omnivore_median_age',6)
